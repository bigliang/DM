# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
item_categories=pd.read_csv('item_categories.csv')
items=pd.read_csv('items.csv')
sales_train=pd.read_csv('sales_train.csv')
shops=pd.read_csv('shops.csv')
test=pd.read_csv('test.csv')

# %%
data.dtypes
# Out:
# date               object
# date_block_num      int64
# shop_id             int64
# item_id             int64
# item_price        float64
# item_cnt_day      float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
# date              object
# date_block_num    int64
# shop_id           int64
# item_id           int64
# item_price        float64
# item_cnt_day      float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
data.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908532e+02  1.242641e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.618834e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03

# %%
data['item_price'].describe()
# Out:
# count    2.935849e+06
# mean     8.908532e+02
# std      1.729800e+03
# min     -1.000000e+00
# 25%      2.490000e+02
# 50%      3.990000e+02
# 75%      9.990000e+02
# max      3.079800e+05
# Name: item_price, dtype: float64

# %%
data['shop_id'].unique().shape
# Out:
# (60,)

# %%
data['item_id'].unique().shape
# Out:
# (21807,)

# %% [markdown]
# there are total 60 shops and total 21807 unique items. And the date ranges from

# %% [markdown]
# entries number and date_block_number

# %%
sns.countplot(x='date_block_num', data=sales_train)
plt.show()

# %% [markdown]
# we can clearly see that there are more records for Decembers of every year. I think it is because People tend to buy more items during the Chrismas. Actually it is a seasonality. We can also find a trend that the entries are becoming fewer from 2013 to 2014.

# %%
item entries of different shop

# %%
sns.countplot(x='shop_id', data=sales_train)
plt.show()

# %% [markdown]
# the shop 31 and 25 has the most bumber of entires, they may make a great contribution to the total sales trends.Therefore we need discover further for this two shops.

# %%
shop31=sales_train[sales_train['shop_id']==31]
shop31.head()
# Out:
#              date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 60143  03.01.2013               0       31     4906      1794.0           2.0
# 60144  02.01.2013               0       31     4906      1789.0           1.0
# 60145  11.01.2013               0       31     4890       799.0           1.0
# 60146  26.01.2013               0       31     4901      1499.0           1.0
# 60147  25.01.2013               0       31     4901      1499.0           1.0

# %%
sns.countplot(x='date_block_num', data=shop31)
plt.show()

# %% [raw]
# the trend for the shop 31 is similar for the total sales's trend, especially for the decembers of 2013 and 2014, it sold at least 10000 entries.The sales entries of this shop is above the average of every month.

# %%
sales_month = sales_train.groupby(['date_block_num'])['item_cnt_day'].sum()

# %%
sales_month=pd.DataFrame(sales_month)

# %%
sales_month.to_csv('sales_month.csv')

# %%
salse_month=pd.read_csv('sales_month.csv')

# %% [markdown]
# total item sold of every month

# %%
sns.barplot(x="date_block_num", y="item_cnt_day", data=salse_month , order=salse_month['date_block_num'])
plt.show()

# %% [raw]
# we can see that the total sales's trend is related to the record number of every month.But the number of item sold every month is much than the number of the record, since each item can be sold more than once. There is also a seasonality trend. For time series prediction, we need to remove the trend in the future.

# %%
dt = sales_train.iloc[:,:].values
dt[:,4:5]
revenue=np.multiply(dt[:,4:5],dt[:,5:])
revenue
# Out:
# array([[999.0],
#        [899.0],
#        [-899.0],
#        ...,
#        [349.0],
#        [299.0],
#        [299.0]], dtype=object)

# %%
re = pd.DataFrame(revenue)
re.columns = ['revenue']
new_salse=pd.concat([sales_train,re],axis=1) 
new_salse.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0
#
#    revenue
# 0      999
# 1      899
# 2     -899
# 3  1709.05
# 4     1099

# %%
sales_price = new_salse.groupby(['date_block_num'])['revenue'].sum()
sales_price.to_frame()
# Out:
# <bound method Series.to_frame of date_block_num
# 0     9.194709e+07
# 1     9.066571e+07
# 2     1.049327e+08
# 3     6.915429e+07
# 4     6.506531e+07
# 5     7.955041e+07
# 6     6.935060e+07
# 7     7.429797e+07
# 8     1.190819e+08
# 9     1.072416e+08
# 10    1.386654e+08
# 11    2.075717e+08
# 12    9.822602e+07
# 13    1.074311e+08
# 14    1.091154e+08
# 15    8.065176e+07
# 16    9.128173e+07
# 17    8.266854e+07
# 18    7.648792e+07
# 19    8.960409e+07
# 20    1.147236e+08
# 21    1.125255e+08
# 22    1.520376e+08
# 23    2.320252e+08
# 24    1.189277e+08
# 25    8.659388e+07
# 26    8.647627e+07
# 27    9.025281e+07
# 28    8.857744e+07
# 29    6.539800e+07
# 30    5.940579e+07
# 31    6.174896e+07
# 32    9.290517e+07
# 33    8.433711e+07
# Name: revenue, dtype: float64>

# %%
sales_price.to_csv('sales_price.csv')
salse_price=pd.read_csv('sales_price.csv')

# %%
sns.barplot(x="date_block_num", y="revenue", data=salse_price , order=salse_price['date_block_num'])
plt.show()

# %% [markdown]
# In the graph, the December of the 2013 and 2014 are also the most top month, but interesting thing is that even the item sold of 2013 is more than the 2014, the total revenue of 2014 is much than 2013.Inaddtion there isn't a decreasing trend for total revenue from 2013 to 2014. That is said, even the number of item sold decrease, the price of each item increase.

# %% [markdown]
# 12/2013 sales suitation

# %%
price_2013=new_salse[new_salse['date_block_num']==11]
price_2013
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 1124316  04.12.2013              11       25    17769       199.0
# 1124317  15.12.2013              11       25    18016       500.0
# 1124318  22.12.2013              11       25    17763       399.0
# 1124319  31.12.2013              11       25    17760      3250.0
# 1124320  18.12.2013              11       25    17763       398.5
# 1124321  06.12.2013              11       25    17763       399.0
# 1124322  03.12.2013              11       25    17763       399.0
# 1124323  31.12.2013              11       25    18016       500.0
# 1124324  28.12.2013              11       25    17760      3250.0
# 1124325  26.12.2013              11       25    17760      3250.0
# 1124326  19.12.2013              11       25    17760      3250.0
# 1124327  19.12.2013              11       25    17763       399.0
# 1124328  11.12.2013              11       25    17781       299.0
# 1124329  08.12.2013              11       25    17787       199.0
# 1124330  09.12.2013              11       25    17785       149.0
# 1124331  17.12.2013              11       25    17802       399.0
# 1124332  16.12.2013              11       25    17802       399.0
# 1124333  15.12.2013              11       25    17802       399.0
# 1124334  14.12.2013              11       25    17802       399.0
# 1124335  13.12.2013              11       25    17802       399.0
# 1124336  21.12.2013              11       25    17802       399.0
# 1124337  04.12.2013              11       25    17785       149.0
# 1124338  12.12.2013              11       25    17802       399.0
# 1124339  10.12.2013              11       25    17802       399.0
# 1124340  29.12.2013              11       25    17799       299.0
# 1124341  28.12.2013              11       25    17792       349.0
# 1124342  19.12.2013              11       25    17794       149.0
# 1124343  09.12.2013              11       25    17794       149.0
#          item_cnt_day revenue
# 2192637           1.0     299
# 2192638           1.0     399
# 2192639           1.0     399
# 2192640           1.0     399
# 2192641           2.0     798
# 2192642           1.0     399
# 2192643           2.0     298
# 2192644           2.0     298
# 2192645           1.0     149
# 2192646           1.0     149
# 2192647           1.0     149
# 2192648           2.0     798
# 2192649           1.0   217.5
# 2192650           2.0     798
# 2192651           3.0    3299
# 2192652           1.0     149
# 2192653           1.0     499
# 2192654           1.0     499
# 2192655           2.0     998
# 2192656           1.0     299
# 2192657           1.0     149
# 2192658           3.0    5598
# 2192659           4.0    4998
# 2192660           1.0    1799
# 2192661           2.0    3798
# 2192662           2.0    2498
# 2192663           1.0    1799
# 2192664           6.0    8597
# 2192665           2.0    3000
# 2192666           3.0    4990
# ...               ...     ...
# 2323393           1.0     998
# 2323394           1.0     399
# 2323395           1.0     399
# 2323396           2.0     798
# 2323397           1.0     799
# 2323398           1.0     799
# 2323399           1.0     799
# 2323400           1.0     799
# 2323401           1.0     498
# 2323402           1.0    1199
# 2323403           2.0    2398
# 2323404           2.0    3998
# 2323405           1.0     299
# 2323406           1.0     299
# 2323407           1.0     299
# 2323408           1.0     299
# 2323409           1.0     299
# 2323410           2.0     598
# 2323411           1.0    1199
# 2323412           2.0   597.7
# 2323413           2.0     598
# 2323414           1.0    1499
# 2323415           1.0    1499
# 2323416           1.0    1499
# 2323417           1.0    2599
# 2323418           1.0    2599
# 2323419           2.0    3998
# 2323420           1.0    2999
# 2323421           1.0    1199
# 2323422           1.0    1999
#
# [130786 rows x 7 columns]

# %%
sales_day14 =price_2014.groupby(['date']).sum()
sales_day14
sales_day14.index.values
sales_day14['dd']=sales_day.index.values

# %%
sns.barplot(x="dd", y="item_cnt_day", data=sales_day14 , order=sales_day14['dd'] )
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# It can justify our arguments that people tend to buy more items for the chrismas day.To specific, after the chrismas people tend to buy more things for the New Year's day.The biggest day is six time than the worst day of these month.

# %%
sales_date=new_salse.groupby(['date']).sum()
sales_date['item_cnt_day'].describe()
# Out:
# count     1034.000000
# mean      3528.245648
# std       1584.687467
# min       1274.000000
# 25%       2472.250000
# 50%       3145.000000
# 75%       4257.000000
# max      13343.000000
# Name: item_cnt_day, dtype: float64

# %% [markdown]
# the mean of the total items sold for every month ranges from 1274 to 13343 and the average number of sold items is 3528.Even the range is so big, we don't need to scale it since we need to predict the true number of the items.

# %%
item_categories
# Out:
#                           item_category_name  item_category_id
# 0                    PC - Гарнитуры/Наушники                 0
# 1                           Аксессуары - PS2                 1
# 2                           Аксессуары - PS3                 2
# 3                           Аксессуары - PS4                 3
# 4                           Аксессуары - PSP                 4
# 5                        Аксессуары - PSVita                 5
# 6                      Аксессуары - XBOX 360                 6
# 7                      Аксессуары - XBOX ONE                 7
# 8                             Билеты (Цифра)                 8
# 9                            Доставка товара                 9
# 10                     Игровые консоли - PS2                10
# 11                     Игровые консоли - PS3                11
# 12                     Игровые консоли - PS4                12
# 13                     Игровые консоли - PSP                13
# 14                  Игровые консоли - PSVita                14
# 15                Игровые консоли - XBOX 360                15
# 16                Игровые консоли - XBOX ONE                16
# 17                  Игровые консоли - Прочие                17
# 18                                Игры - PS2                18
# 19                                Игры - PS3                19
# 20                                Игры - PS4                20
# 21                                Игры - PSP                21
# 22                             Игры - PSVita                22
# 23                           Игры - XBOX 360                23
# 24                           Игры - XBOX ONE                24
# 25                 Игры - Аксессуары для игр                25
# 26                      Игры Android - Цифра                26
# 27                          Игры MAC - Цифра                27
# 28          Игры PC - Дополнительные издания                28
# 29           Игры PC - Коллекционные издания                29
# ..                                       ...               ...
# 54                             Книги - Цифра                54
# 55       Музыка - CD локального производства                55
# 56       Музыка - CD фирменного производства                56
# 57                              Музыка - MP3                57
# 58                            Музыка - Винил                58
# 59                Музыка - Музыкальное видео                59
# 60               Музыка - Подарочные издания                60
# 61                      Подарки - Атрибутика                61
# 62          Подарки - Гаджеты, роботы, спорт                62
# 63                  Подарки - Мягкие игрушки                63
# 64                 Подарки - Настольные игры                64
# 65    Подарки - Настольные игры (компактные)                65
# 66              Подарки - Открытки, наклейки                66
# 67                        Подарки - Развитие                67
# 68             Подарки - Сертификаты, услуги                68
# 69                        Подарки - Сувениры                69
# 70            Подарки - Сувениры (в навеску)                70
# 71  Подарки - Сумки, Альбомы, Коврики д/мыши                71
# 72                         Подарки - Фигурки                72
# 73              Программы - 1С:Предприятие 8                73
# 74                   Программы - MAC (Цифра)                74
# 75              Программы - Для дома и офиса                75
# 76      Программы - Для дома и офиса (Цифра)                76
# 77                     Программы - Обучающие                77
# 78             Программы - Обучающие (Цифра)                78
# 79                                 Служебные                79
# 80                        Служебные - Билеты                80
# 81                   Чистые носители (шпиль)                81
# 82                 Чистые носители (штучные)                82
# 83                          Элементы питания                83
#
# [84 rows x 2 columns]

# %%
from googletrans import Translator
index =0
translator = Translator()
for row in item_categories["item_category_name"]:
    english_word = translator.translate(row)
    item_categories.iloc[index,0] = english_word.text
    index=index+1

# %%
item_categories
# Out:
#                      item_category_name  item_category_id
# 0            PC - Headsets / Headphones                 0
# 1                     Accessories - PS2                 1
# 2                     Accessories - PS3                 2
# 3                     Accessories - PS4                 3
# 4                     Accessories - PSP                 4
# 5                  Accessories - PSVita                 5
# 6                Accessories - XBOX 360                 6
# 7                Accessories - XBOX ONE                 7
# 8                      Tickets (figure)                 8
# 9                     Delivery of goods                 9
# 10                  Game Consoles - PS2                10
# 11                  Game Consoles - PS3                11
# 12                  Game Consoles - PS4                12
# 13                  Game Consoles - PSP                13
# 14               Game Consoles - PSVita                14
# 15             Game Consoles - XBOX 360                15
# 16             Game Consoles - XBOX ONE                16
# 17                Game Consoles - Other                17
# 18                          Games - PS2                18
# 19                          Games - PS3                19
# 20                          Games - PS4                20
# 21                          Games - PSP                21
# 22                       Games - PSVita                22
# 23                     Games - XBOX 360                23
# 24                     Games - XBOX ONE                24
# 25        Games - Accessories for games                25
# 26                Android games - Digit                26
# 27                    MAC Games - Digit                27
# 28        PC Games - Additional Edition                28
# 29       PC Games - Collector's Edition                29
# ..                                  ...               ...
# 54                       Books - Number                54
# 55       Music - CD of local production                55
# 56     Music - CD of branded production                56
# 57                          Music - MP3                57
# 58                        Music - Vinyl                58
# 59                Music - Musical video                59
# 60                 Music - Gift edition                60
# 61                   Gifts - Attributes                61
# 62      Gifts - Gadgets, robots, sports                62
# 63                    Gifts - Soft toys                63
# 64                  Gifts - Board Games                64
# 65        Gifts - Board games (compact)                65
# 66          Gifts - Postcards, stickers                66
# 67                  Gifts - Development                67
# 68       Gifts - Certificates, services                68
# 69                    Gifts - Souvenirs                69
# 70       Gifts - Souvenirs (per sample)                70
# 71     Gifts - Bags, Albums, Mouse pads                71
# 72                      Gifts - Figures                72
# 73          Programs - 1C: Enterprise 8                73
# 74              Programs - MAC (Number)                74
# 75           Programs - Home and Office                75
# 76  Programs - Home and Office (Figure)                76
# 77                  Programs - Teaching                77
# 78        Programs - Teaching (Numbers)                78
# 79                               Office                79
# 80                   Official - Tickets                80
# 81               Clean carriers (spire)                81
# 82                  Clean media (piece)                82
# 83                   Elements of a food                83
#
# [84 rows x 2 columns]

# %% [markdown]
# we can see that many categories are written by Russian Therefore we need to transfer it into English.
# After translation, we find that many catergories belong to the same main categories. For example， the Accessories - PS2,Accessories-PS3, Accessories - PS4 are all belongs to the same category--Accessories. So we can aggregate them into the same category.

# %%
from googletrans import Translator
index =0
translator = Translator()
for row in items["item_name"]:
    english_word = translator.translate(row)
    items.iloc[index,0] = english_word.text
    index=index+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/shihongliang/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383             try:  # Python 2.7, use buffering of HTTP responses
# --> 384                 httplib_response = conn.getresponse(buffering=True)
#     385             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-169-4c2a76b3e271> in <module>()
#       3 translator = Translator()
#       4 for row in items["item_name"]:
# ----> 5     english_word = translator.translate(row)
#       6     items.iloc[index,0] = english_word.text
#       7     index=index+1
#
# /Users/shihongliang/anaconda/lib/python3.6/site-packages/googletrans/client.py in translate(self, text, dest, src)
#     130
#     131         origin = text
# --> 132         data = self._translate(text, dest, src)
#     133
#     134         # this code will be updated when the format is changed.
#
# /Users/shihongliang/anaconda/lib/python3.6/site-packages/googletrans/client.py in _translate(self, text, dest, src)
#      59                                     token=token)
#      60         url = urls.TRANSLATE.format(host=self._pick_service_url())
# ---> 61         r = self.session.get(url, params=params)
#      62
#      63         data = utils.format_json(r.text)
#
# /Users/shihongliang/anaconda/lib/python3.6/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     499
#     500         kwargs.setdefault('allow_redirects', True)
# --> 501         return self.request('GET', url, **kwargs)
#     502
#     503     def options(self, url, **kwargs):
#
# /Users/shihongliang/anaconda/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /Users/shihongliang/anaconda/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /Users/shihongliang/anaconda/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /Users/shihongliang/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     592                                                   timeout=timeout_obj,
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#     596             # If we're going to release the connection in ``finally:``, then
#
# /Users/shihongliang/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385             except TypeError:  # Python 2.6 and older, Python 3
#     386                 try:
# --> 387                     httplib_response = conn.getresponse()
#     388                 except Exception as e:
#     389                     # Remove the TypeError from the exception chain in Python 3;
#
# /Users/shihongliang/anaconda/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /Users/shihongliang/anaconda/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Users/shihongliang/anaconda/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Users/shihongliang/anaconda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /Users/shihongliang/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     254     def recv_into(self, *args, **kwargs):
#     255         try:
# --> 256             return self.connection.recv_into(*args, **kwargs)
#     257         except OpenSSL.SSL.SysCallError as e:
#     258             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /Users/shihongliang/anaconda/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1332             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1333         else:
# -> 1334             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1335         self._raise_ssl_error(self._ssl, result)
#    1336
#
# KeyboardInterrupt:

# %%
category=items.groupby(['item_category_id']).count()
category['category_name']=item_categories["item_category_name"]

# %%
# Out:
#                                                item_name  item_id  \
# 0                 !! IN THE POWER OF HAPPINESS (PLAST) D        0
# 1      ! ABBYY FineReader 12 Professional Edition Ful...        1
# 2                  *** IN THE GLORY OF THE GLORY (UNV) D        2
# 3                                 *** BLUE WAVE (Univ) D        3
# 4                                      *** BOX (GLASS) D        4
# 5                      *** NEW AMERICAN GRAPHICS (UNI) D        5
# 6                         *** BLOCK ON THE GATES (UNI) D        6
# 7                            *** SHOCK AT DOOR-2 (UNI) D        7
# 8                               *** TEA WITH MUSSOLINI D        8
# 9                         *** SHUGARLEND EXPRESS (UNI) D        9
# 10                               * Beyond Death's Edge D       10
# 11                                  * LINE OF COMMENTS D       11
# 12                     * MICHAEL AND JUMANJI Female love       12
# 13                                      * SAVING EMILY D       13
# 14                       * PRIVATE PROFESSOR / MAGIC / D       14
# 15                // ADRENALIN: ONE AGAINST ALL (Region)       15
# 16                           // MONGOL S.Bodrov (Region)       16
# 17                   // NOT OBSERVING THE TRACK (Region)       17
# 18                       / BOMB FOR THE BRIDE / 2DVD / D       18
# 19                          / GOLDEN COLLECTION m / f-72       19
# 20                                     / ONCE IN CHINA-2       20
# 21                                          /LAST CHANCE       21
# 22                                     / CURED EL CHARRO       22
# 23                               / NORTH AND SOUTH / N.2       23
# 24                                   / THE DEATH PASSAGE       24
# 25                                         /YOU ARE DEAD       25
# 26                  / MULTIPLE FREQUENCY vol.2 (ser.3-4)       26
# 27                    007 Legends [PS3, Russian version]       27
# 28              007 Legends [PC, Jewel, Russian version]       28
# 29               007 Legends [Xbox 360, Russian version]       29
# ...                                                  ...      ...
# 22140                                      Я, РОБОТ (BD)    22140
# 22141                                  Я, СНОВА Я И МАМА    22141
# 22142                             Я, СНОВА Я И МАМА (BD)    22142
# 22143                                    Я, ФРАНКЕНШТЕЙН    22143
# 22144                            Я, ФРАНКЕНШТЕЙН (3D BD)    22144
# 22145                               Я, ФРАНКЕНШТЕЙН (BD)    22145
# 22146                                  Я-ЛЕГЕНДА WB (BD)    22146
# 22147                              Я-ЛЕГЕНДА WB (регион)    22147
# 22148                                    Я-ЧЕТВЕРТЫЙ  WD    22148
# 22149                           Я-ЧЕТВЕРТЫЙ  WD (регион)    22149
# 22150                                   Я-ЧЕТВЕРТЫЙ (BD)    22150
# 22151                                     ЯВЛЕНИЕ (2012)    22151
# 22152                            ЯВЛЕНИЕ (2012) (регион)    22152
# 22153                                       ЯВЛЕНИЕ (BD)    22153
# 22154                                  ЯВЛЕНИЕ 2012 (BD)    22154
# 22155         ЯДЫ, ИЛИ ВСЕМИРНАЯ ИСТОРИЯ ОТРАВЛЕНИЙ (BD)    22155
# 22156     ЯДЫ, ИЛИ ВСЕМИРНАЯ ИСТОРИЯ ОТРАВЛЕНИЙ (регион)    22156
# 22157                                            ЯЛТА 45    22157
# 22158                                          ЯМА (rem)    22158
# 22159                                          ЯНКОВСКИЙ    22159
# 22160                         ЯРМАРКА ТЩЕСЛАВИЯ (Регион)    22160
# 22161                   ЯРОСЛАВ. ТЫСЯЧУ ЛЕТ НАЗАД э (BD)    22161
# 22162                                             ЯРОСТЬ    22162
# 22163                                   ЯРОСТЬ ( регион)    22163
# 22164                                        ЯРОСТЬ (BD)    22164
# 22165             Ядерный титбит 2 [PC, Цифровая версия]    22165
# 22166    Язык запросов 1С:Предприятия  [Цифровая версия]    22166
# 22167  Язык запросов 1С:Предприятия 8 (+CD). Хрустале...    22167
# 22168                                Яйцо для Little Inu    22168
# 22169                      Яйцо дракона (Игра престолов)    22169
#
#        item_category_id
# 0                    40
# 1                    76
# 2                    40
# 3                    40
# 4                    40
# 5                    40
# 6                    40
# 7                    40
# 8                    40
# 9                    40
# 10                   40
# 11                   40
# 12                   55
# 13                   40
# 14                   40
# 15                   40
# 16                   40
# 17                   40
# 18                   40
# 19                   40
# 20                   40
# 21                   40
# 22                   40
# 23                   40
# 24                   40
# 25                   40
# 26                   40
# 27                   19
# 28                   30
# 29                   23
# ...                 ...
# 22140                37
# 22141                40
# 22142                37
# 22143                40
# 22144                38
# 22145                37
# 22146                37
# 22147                40
# 22148                40
# 22149                40
# 22150                37
# 22151                40
# 22152                40
# 22153                37
# 22154                37
# 22155                37
# 22156                40
# 22157                40
# 22158                40
# 22159                40
# 22160                40
# 22161                37
# 22162                40
# 22163                40
# 22164                37
# 22165                31
# 22166                54
# 22167                49
# 22168                62
# 22169                69
#
# [22170 rows x 3 columns]

# %%
categorysales=pd.merge(new_salse, items, on='item_id')

# %%
categorysales=pd.merge(categorysales, item_categories, on='item_category_id')

# %%
categorysales['revenue']=categorysales[['revenue']].astype(float)
categorysales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2935849 entries, 0 to 2935848
# Data columns (total 10 columns):
# date                  object
# date_block_num        int64
# shop_id               int64
# item_id               int64
# item_price            float64
# item_cnt_day          float64
# revenue               float64
# item_name             object
# item_category_id      int64
# item_category_name    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 246.4+ MB

# %%
categorysum=categorysales.groupby(['item_category_name']).sum()

# %% [markdown]
# top 20 categories of sold item

# %%
categorysum.index.values
categorysum['item_category_name']=categorysum.index.values
categorysum_top20=categorysum.sort_values(by=['item_cnt_day'],ascending=False).head(20)
sns.barplot(y="item_category_name", x="item_cnt_day", data=categorysum_top20)
plt.show()

# %% [markdown]
# We can find that the best selling for all categories is Cinema-DVD, but we can see in the top20 best seelling categories, most of them are about Games and Gifts. We can assume that people tend to buy the Gifts and Games and send to others as the chrismas or New year's day gift accroding to the trend we observed before about the items sold trend.In addition, we can discover more about the relationship between categories and revenue.

# %% [markdown]
# top 20 most revenue

# %%
categoryprice_top20=categorysum.sort_values(by=['revenue'],ascending=False).head(20)
sns.barplot(y="item_category_name", x="revenue", data=categoryprice_top20)
plt.show()

# %% [markdown]
# We can see that also all most profitable items are related to the Games. It can justify our arguments about the people tend to buy Games. But we need to discover further about the relation ship with month.

# %%
categorymonth11=categorysales[categorysales['date_block_num']==11].groupby(['item_category_name']).sum()

# %% [markdown]
# category suitation of 12/2013

# %%
categorymonth11.index.values
categorymonth11['item_category_name']=categorymonth11.index.values
category11_top20=categorymonth11.sort_values(by=['item_cnt_day'],ascending=False).head(20)
sns.barplot(y="item_category_name", x="item_cnt_day", data=category11_top20)
plt.show()

# %% [markdown]
# But the truth is that people tend to buy more Cinema-DVD on the December of 2013...

# %% [markdown]
# we allocate the categories into main categories of them

# %% [markdown]
# allocate my own main category

# %%
categorysales['main_category']=categorysales.item_category_name.str.extract('([A-Za-z\ ]+)', expand=False)

# %%
categorysales['main_category'].unique()
# Out:
# array(['Cinema ', 'Music ', 'Games ', 'PC Games ', 'Programs ', 'Books ',
#        'Gifts ', 'Accessories ', 'Game Consoles ', 'Payment cards ',
#        'Clean media ', 'Clean carriers ', 'Office', 'PC ',
#        'Elements of a food', 'Delivery of goods', ' ', 'Tickets ',
#        'Android games ', 'MAC Games ', 'Official ', 'Payment Cards '], dtype=object)

# %%
categorymonth_main=categorysales.groupby(['main_category']).sum()
categorymonth_main['main_category']=categorymonth_main.index.values
category_main_top20=categorymonth_main.sort_values(by=['item_cnt_day'],ascending=False).head(20)

# %%
sns.barplot(y="main_category", x="item_cnt_day", data=category_main_top20)
plt.show()

# %% [markdown]
# 12/2013 main category suitation

# %%
categorymonth_11_main=categorysales[categorysales['date_block_num']==11].groupby(['main_category']).sum()

# %%
categorymonth_11_main.index.values
categorymonth_11_main['main_category']=categorymonth_11_main.index.values
category_11_main_top20=categorymonth_11_main.sort_values(by=['item_cnt_day'],ascending=False).head(20)
category_11_main_top20
sns.barplot(y="main_category", x="item_cnt_day", data=category_11_main_top20)
plt.show()

# %% [markdown]
# total sold item revenue  suitation of main category

# %%
category_main_price_top20=categorymonth_main.sort_values(by=['revenue'],ascending=False).head(20)
category_main_price_top20
sns.barplot(y="main_category", x='revenue', data=category_main_price_top20)
plt.show()

# %% [markdown]
# 12/2013 revenue main category

# %%
category_11_price_top20=categorymonth_11_main.sort_values(by=['revenue'],ascending=False).head(20)
category_11_price_top20
sns.barplot(y="main_category", x='revenue', data=category_11_price_top20)
plt.show()

# %% [markdown]
# But the Games and Game Consoles makes more contribution to the total Avune for December. It can make sense that Game Console are more expensive than the CDs or other things.

# %%
categorymonth_23_main=categorysales[categorysales['date_block_num']==23].groupby(['main_category']).sum()
categorymonth_23_main.index.values
categorymonth_23_main['main_category']=categorymonth_11_main.index.values
category_23_main_top20=categorymonth_23_main.sort_values(by=['item_cnt_day'],ascending=False).head(20)
category_23_main_top20
sns.barplot(y="main_category", x="item_cnt_day", data=category_23_main_top20)
plt.show()

# %%
category_23_price_top20=categorymonth_23_main.sort_values(by=['revenue'],ascending=False).head(20)
category_23_price_top20
sns.barplot(y="main_category", x='revenue', data=category_23_price_top20)
plt.show()

# %%
category_main=categorysales.groupby(['main_category','date_block_num']).sum()
